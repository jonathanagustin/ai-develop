# %% [markdown]
# ---
# **AUTO-GENERATE PDFs ON PUSH TO BRANCH**
# 1. PDFs are autogenerated every time you push to a `BRANCH`
# 1. After pushing to a branch, go to branch: `output-[BRANCH-YOU-PUSHED-TO]`
# 1. Then go to the folder called `output`

# %% [markdown]
# ---
# **COMMAND TO CONVERT NOTEBOOK TO PDF**

# %%
# RUN THIS CELL TO CONVERT THIS NOTEBOOK TO PDF
# !jupyter nbconvert --to pdf example.ipynb

# %% [markdown]
# ---
# **AUTOFORMAT ALL PYTHON FILES**

# %%
try:
    import black
except ImportError:
    # %pip install black[jupyter]
    import black

# %autosave 0
# !black .
# Out:
# Autosave disabled
# All done! ✨ 🍰 ✨
# 2 files left unchanged.
